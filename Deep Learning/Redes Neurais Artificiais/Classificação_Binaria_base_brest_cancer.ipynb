# %% [markdown]
# <a href="https://colab.research.google.com/github/Matheusbcy/-Data-Science-IA-/blob/main/Deep%20Learning/Redes%20Neurais%20Artificiais/Classifica%C3%A7%C3%A3o_Binaria_base_brest_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classificação binária - Brest Cancer simples

# %%
import pandas as pd

# %%
# Atributos Previsores

X = pd.read_csv("/content/entradas_breast.csv")
X
# Out:
#       radius_mean   texture_mean   perimeter_mean   area_mean  \
# 0           17.99          10.38           122.80      1001.0
# 1           20.57          17.77           132.90      1326.0
# 2           19.69          21.25           130.00      1203.0
# 3           11.42          20.38            77.58       386.1
# 4           20.29          14.34           135.10      1297.0
# ..            ...            ...              ...         ...
# 564         21.56          22.39           142.00      1479.0
# 565         20.13          28.25           131.20      1261.0
# 566         16.60          28.08           108.30       858.1
# 567         20.60          29.33           140.10      1265.0
# 568          7.76          24.54            47.92       181.0
#
#       smoothness_mean   compactness_mean   concavity_mean  \
# 0             0.11840            0.27760          0.30010
# 1             0.08474            0.07864          0.08690
# ...

# %%
# Classe
y = pd.read_csv("/content/saidas_breast.csv")
y
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 564  0
# 565  0
# 566  0
# 567  0
# 568  1
#
# [569 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X, y, test_size = 0.25, random_state = 1)

# %%
X_treinamento.shape, y_treinamento.shape
# Out:
# ((426, 30), (426, 1))

# %%
X_teste.shape, y_teste.shape
# Out:
# ((143, 30), (143, 1))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential

# %%
rede_neural = Sequential([
    tf.keras.layers.InputLayer(shape = (30, )),
    tf.keras.layers.Dense(units = 16, activation = "relu", kernel_initializer = "random_uniform"),
    tf.keras.layers.Dense(units = 16, activation = "relu", kernel_initializer = "random_uniform"),
    tf.keras.layers.Dense(units = 1, activation = "sigmoid")
])

# %%
rede_neural.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 785 (3.07 KB)
#  Trainable params: 785 (3.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
rede_neural.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["binary_accuracy"])

# %%
rede_neural.fit(X_treinamento, y_treinamento, batch_size = 10, epochs = 100)

# %%
previsoes = rede_neural.predict(X_teste)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
previsoes = previsoes > 0.5

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy_score(y_teste, previsoes)
# Out:
# 0.9020979020979021

# %%
confusion_matrix(y_teste, previsoes)
# Out:
# array([[45, 10],
#        [ 4, 84]])

# %%
rede_neural.evaluate(X_teste, y_teste)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.9001 - loss: 0.2633
# [0.2544076442718506, 0.9020978808403015]

# %% [markdown]
# # Validação cruzada

# %%
# !pip install scikeras

# %%
# !pip install scikit-learn==1.5.2

# %%
import scikeras
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import cross_val_score
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
X = pd.read_csv("/content/entradas_breast.csv")
y = pd.read_csv("/content/saidas_breast.csv")

# %%
X = X.values
y = y.values.ravel()

# %%
def criar_rede():
    K.clear_session()
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer,
                  loss="binary_crossentropy",
                  metrics=["accuracy"])
    return model

# %%
rede_neural = KerasClassifier(model=criar_rede, epochs=100, batch_size=10)

# %%
resultados = cross_val_score(estimator=rede_neural, X=X, y=y, cv=10, scoring="accuracy")

# %%
resultados
# Out:
# array([0.84210526, 0.85964912, 0.89473684, 0.94736842, 0.8245614 ,
#        0.87719298, 0.87719298, 0.87719298, 0.80701754, 0.91071429])

# %%
resultados.mean()
# Out:
# np.float64(0.8717731829573936)

# %%
resultados.std()
# Out:
# np.float64(0.03911000516658108)

# %% [markdown]
# # Overfitting - Dropout

# %%
# Não recomendado pois pode excluir dados importantes
def criar_rede_dropout():
    K.clear_session()
    model = Sequential([
        tf.keras.layers.InputLayer(shape= (30, )),
        tf.keras.layers.Dense(units = 16, activation = "relu", kernel_initializer = "random_uniform"),
        tf.keras.layers.Dropout(rate = 0.2),
        tf.keras.layers.Dense(units = 16, activation = "relu", kernel_initializer = "random_uniform"),
        tf.keras.layers.Dropout(rate = 0.2),
        tf.keras.layers.Dense(units = 1, activation = "sigmoid"),
    ])
    optimizer = Adam(learning_rate=0.001, clipvalue = 0.5)
    model.compile(optimizer=optimizer,
                  loss="binary_crossentropy",
                  metrics=["accuracy"])
    return model

# %%
rede_neural = KerasClassifier(model=criar_rede_dropout, epochs=100, batch_size=10)

# %%
resultados = cross_val_score(estimator=rede_neural, X=X, y=y, cv=10, scoring="accuracy")

# %%
resultados
# Out:
# array([0.9122807 , 0.78947368, 0.85964912, 0.9122807 , 0.89473684,
#        0.9122807 , 0.87719298, 0.89473684, 0.85964912, 0.91071429])

# %%
resultados.mean()
# Out:
# np.float64(0.8822994987468672)

# %%
resultados.std()
# Out:
# np.float64(0.03671808839354637)

# %% [markdown]
# # Tuning dos parâmetros

# %%
from sklearn.model_selection import GridSearchCV

# %%
X = pd.read_csv("/content/entradas_breast.csv")
y = pd.read_csv("/content/saidas_breast.csv")

# %%
# Não recomendado pois pode excluir dados importantes
def criar_rede_dropout(optimizer, loss, kernel_initializer, activation, neurons):
    K.clear_session()
    model = Sequential([
        tf.keras.layers.InputLayer(shape= (30, )),
        tf.keras.layers.Dense(units = neurons, activation = activation, kernel_initializer = kernel_initializer),
        tf.keras.layers.Dropout(rate = 0.2),
        tf.keras.layers.Dense(units = neurons, activation = activation, kernel_initializer = kernel_initializer),
        tf.keras.layers.Dropout(rate = 0.2),
        tf.keras.layers.Dense(units = 1, activation = "sigmoid"),
    ])

    model.compile(optimizer= optimizer,
                  loss= loss,
                  metrics=["binary_accuracy"])
    return model

# %%
rede_neural = KerasClassifier(model = criar_rede_dropout)

# %% [markdown]
# Poucos parâmetros para não demorar muito

# %%
params = {
    "batch_size": [10, 30],
    "epochs": [50],
    "model__optimizer": ["adam"],
    "model__loss": ["binary_crossentropy"],
    "model__kernel_initializer": ["random_uniform", "normal"],
    "model__activation": ["relu"],
    "model__neurons": [16]
}

# %%
grid_search = GridSearchCV(estimator = rede_neural, param_grid = params, scoring = "accuracy", cv = 5)

# %%
grid_search = grid_search.fit(X, y)

# %%
best_params = grid_search.best_params_

# %%
best_params
# Out:
# {'batch_size': 30,
#  'epochs': 50,
#  'model__activation': 'relu',
#  'model__kernel_initializer': 'random_uniform',
#  'model__loss': 'binary_crossentropy',
#  'model__neurons': 16,
#  'model__optimizer': 'adam'}

# %%
best_precision = grid_search.best_score_
print(best_precision)
# Out:
# 0.8893339543549137

# %% [markdown]
# # Classificação de um registro

# %%
import numpy as np

# %%
model = Sequential([
    tf.keras.layers.InputLayer(shape= (30, )),
    tf.keras.layers.Dense(units = 16, activation = "relu", kernel_initializer = "random_uniform"),
    tf.keras.layers.Dropout(rate = 0.2),
    tf.keras.layers.Dense(units = 16, activation = "relu", kernel_initializer = "random_uniform"),
    tf.keras.layers.Dropout(rate = 0.2),
    tf.keras.layers.Dense(units = 1, activation = "sigmoid"),
])

model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["binary_accuracy"])
model.fit(X, y, batch_size = 10, epochs = 50)
# Out:
# Epoch 1/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary_accuracy: 0.5185 - loss: 1.7137
# Epoch 2/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.6313 - loss: 0.5930
# Epoch 3/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.6427 - loss: 0.5832
# Epoch 4/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.6974 - loss: 0.4945
# Epoch 5/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.7408 - loss: 0.4726
# Epoch 6/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.7625 - loss: 0.4735
# Epoch 7/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.7965 - loss: 0.4590
# Epoch 8/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.8128 - loss: 0.4249
# Epoch 9/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8214 - loss: 0.4204
# Epoch 10/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.8318 - loss: 0.4052
# Epoch 11/50
# ...

# %%
new = np.array([[15.80, 8.34, 118, 900, 0.10, 0.26, 0.08, 0.134, 0.178, 0.20,
    0.05, 1098, 0.87, 4500, 145.2, 0.005, 0.04, 0.05, 0.015, 0.03,
    0.007, 23.15, 16.64, 178.5, 2018, 0.14, 0.185, 0.84, 158, 0.363]])

# %%
new
# Out:
# array([[1.580e+01, 8.340e+00, 1.180e+02, 9.000e+02, 1.000e-01, 2.600e-01,
#         8.000e-02, 1.340e-01, 1.780e-01, 2.000e-01, 5.000e-02, 1.098e+03,
#         8.700e-01, 4.500e+03, 1.452e+02, 5.000e-03, 4.000e-02, 5.000e-02,
#         1.500e-02, 3.000e-02, 7.000e-03, 2.315e+01, 1.664e+01, 1.785e+02,
#         2.018e+03, 1.400e-01, 1.850e-01, 8.400e-01, 1.580e+02, 3.630e-01]])

# %%
prev = model.predict(new)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step

# %%
prev = prev > 0.5

# %%
if prev:
  print("Malígno")
else:
  print("Benígno")
# Out:
# Malígno

# %% [markdown]
# # Salvando modelo treinado

# %%
model.save("classificador_breast.keras")

# %% [markdown]
# # Carregando modelo treinado

# %%
classificador_new = tf.keras.models.load_model("/content/classificador_breast.keras")

# %%
classificador_new.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 16)             │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            17 │
# ...

# %%
classificador_new.predict(new)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# array([[1.]], dtype=float32)
