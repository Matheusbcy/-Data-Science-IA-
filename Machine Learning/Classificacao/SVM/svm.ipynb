# %%
# !pip install yellowbrick

# %%
import pickle

import numpy as np

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from yellowbrick.classifier import ConfusionMatrix

# %%
with open("cover_type.pkl", "rb") as f:
    X_cover_treinamento, y_cover_treinamento, X_cover_teste, y_cover_teste = pickle.load(f)

# %%
X_cover_treinamento.shape, y_cover_treinamento.shape
# Out:
# ((7500, 53), (7500,))

# %%
svm_cover = SVC(kernel="rbf", C=2.0, random_state=0)
svm_cover.fit(X_cover_treinamento, y_cover_treinamento)
# Out:
# SVC(C=2.0, random_state=0)

# %%
y_pred = svm_cover.predict(X_cover_teste)

# %%
accuracy = accuracy_score(y_cover_teste, y_pred)
print(f"Acurácia: {accuracy:.2f}")
# Out:
# Acurácia: 0.78

# %%
cm = ConfusionMatrix(svm_cover)
cm.fit(X_cover_treinamento, y_cover_treinamento)
cm.score(X_cover_teste, y_cover_teste)
# Out:
# 0.7808

# %%
print(classification_report(y_cover_teste, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.09      0.16        34
#            1       0.75      0.56      0.64        16
#            2       0.59      0.34      0.43        67
#            3       0.89      0.68      0.77        87
#            4       0.79      0.86      0.82      1230
#            5       0.71      0.80      0.75       156
#            6       0.78      0.74      0.76       910
#
#     accuracy                           0.78      2500
#    macro avg       0.79      0.58      0.62      2500
# weighted avg       0.78      0.78      0.77      2500
