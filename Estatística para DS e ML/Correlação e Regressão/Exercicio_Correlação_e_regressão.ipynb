# %% [markdown]
# <a href="https://colab.research.google.com/github/Matheusbcy/-Data-Science-IA-/blob/main/Exercicio_Correla%C3%A7%C3%A3o_e_regress%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercicio 1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/house_prices.csv")
df.dropna()
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.select_dtypes(include=['number']).corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %% [markdown]
# A Maior correlação com o preço é o sqrt_living

# %%
plt.figure(figsize = (20, 20))
sns.heatmap(df.select_dtypes(include = ["number"]).corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # Exercicio 2 - Utilizar todos os atributos para prever preço de uma casa

# %%
df = pd.read_csv("/content/house_prices.csv")

# %%
import math

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df.drop(labels = ["id", "date"], axis = 1, inplace = True)

# %%
df.drop(labels = ["sqft_living15", "sqft_lot15"], axis = 1, inplace = True)

# %%
X = df.iloc[:, 1:17].values

# %%
y = df.iloc[:, 0].values

# %%
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X, y, test_size = 0.2, random_state = 1)
regressor = LinearRegression()
regressor.fit(X_treinamento, y_treinamento)
prev = regressor.predict(X_teste)

# %%
regressor.score(X_treinamento, y_treinamento)
# Out:
# 0.7028464225751403

# %%
regressor.score(X_teste, y_teste)
# Out:
# 0.6849876187392875

# %%
regressor.coef_
# Out:
# array([-3.18043245e+04,  3.58579292e+04,  1.10548053e+02, -3.00507610e-02,
#         8.22078014e+03,  5.35509806e+05,  5.38454928e+04,  2.70070661e+04,
#         9.93894750e+04,  7.26301445e+01,  3.79179089e+01, -2.53595925e+03,
#         1.98279836e+01, -5.69734345e+02,  6.15129248e+05, -1.99836949e+05])

# %%
regressor.intercept_
# Out:
# np.float64(6514389.053712454)

# %%
mean_absolute_error(y_teste, prev)
# Out:
# 130070.25300649402

# %%
mean_squared_error(y_teste, prev)
# Out:
# 54371442904.1397

# %%
math.sqrt(mean_squared_error(y_teste, prev))
# Out:
# 233176.8489883584
