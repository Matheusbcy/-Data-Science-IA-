# %% [markdown]
# <a href="https://colab.research.google.com/github/Matheusbcy/-Data-Science-IA-/blob/main/PyTorch/Classifica%C3%A7ao%20Binaria/Forma%C3%A7%C3%A3o_Deep_Learning_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto 1: Classificação binária brest cancer

# %% [markdown]
# ## Etapa 1: Importação das bibliotecas

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
import torch
torch.__version__
# Out:
# '2.9.0+cu126'

# %%
import torch.nn as nn

# %% [markdown]
# ## Etapa 2: Base de dados

# %%
np.random.seed(123)
torch.manual_seed(123)

# %%
previsores = pd.read_csv("/content/entradas_breast.csv")
classe = pd.read_csv("/content/saidas_breast.csv")

# %%
previsores.shape
# Out:
# (569, 30)

# %%
previsores.head()
# Out:
#     radius_mean   texture_mean   perimeter_mean   area_mean   smoothness_mean  \
# 0         17.99          10.38           122.80      1001.0           0.11840
# 1         20.57          17.77           132.90      1326.0           0.08474
# 2         19.69          21.25           130.00      1203.0           0.10960
# 3         11.42          20.38            77.58       386.1           0.14250
# 4         20.29          14.34           135.10      1297.0           0.10030
#
#     compactness_mean   concavity_mean  concave_points_mean   symmetry_mean  \
# 0            0.27760           0.3001              0.14710          0.2419
# 1            0.07864           0.0869              0.07017          0.1812
# 2            0.15990           0.1974              0.12790          0.2069
# 3            0.28390           0.2414              0.10520          0.2597
# 4            0.13280         198.0000              0.10430          0.1809
#
#     fractal_dimension_mean  ...   radius_worst   texture_worst  \
# 0                  0.07871  ...          25.38           17.33
# 1                  0.05667  ...          24.99           23.41
# 2                  0.05999  ...          23.57           25.53
# 3                  0.09744  ...          14.91           26.50
# 4                  0.05883  ...          22.54           16.67
#
#     perimeter_worst   area_worst   smoothness_worst   compactness_worst  \
# 0            184.60       2019.0             0.1622              0.6656
# 1            158.80       1956.0             0.1238              0.1866
# 2            152.50       1709.0             0.1444              0.4245
# 3             98.87        567.7             0.2098              0.8663
# 4            152.20       1575.0             0.1374            205.0000
#
#     concavity_worst   concave_points_worst   symmetry_worst  \
# 0            0.7119                 0.2654           0.4601
# 1            0.2416               186.0000         275.0000
# 2            0.4504               243.0000           0.3613
# 3            0.6869                 0.2575           0.6638
# 4            0.4000                 0.1625           0.2364
#
#     fractal_dimension_worst
# 0                   0.11890
# 1                   0.08902
# 2                   0.08758
# 3                 173.00000
# 4                   0.07678
#
# [5 rows x 30 columns]

# %%
classe.head()
# Out:
#    0
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %%
np.unique(classe)
# Out:
# array([0, 1])

# %%
previsores_train, previsores_test, classe_train, classe_test = train_test_split(previsores, classe, test_size=0.25)

# %%
previsores_train.shape, classe_train.shape
# Out:
# ((426, 30), (426, 1))

# %%
previsores_test.shape, classe_test.shape
# Out:
# ((143, 30), (143, 1))

# %% [markdown]
# ## Etapa 3: Transformação dos dados para tensores

# %%
type(np.array(previsores_train))
# Out:
# numpy.ndarray

# %%
previsores_train = torch.tensor(np.array(previsores_train), dtype = torch.float)
classe_train = torch.tensor(np.array(classe_train), dtype = torch.float)

# %%
type(previsores_train), type(classe_train)
# Out:
# (torch.Tensor, torch.Tensor)

# %%
dataset = torch.utils.data.TensorDataset(previsores_train, classe_train)

# %%
type(dataset)

# %%
train_loader = torch.utils.data.DataLoader(dataset, batch_size = 10, shuffle = True)
